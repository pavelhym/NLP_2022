# %%
import os
import nltk
import trax
from trax import layers as tl
from trax.supervised import training
from trax.fastmath import numpy as fastnp
import numpy as np
import pandas as pd
import random as rnd

# set random seeds
trax.supervised.trainer_lib.init_random_number_generators(34)
rnd.seed(34)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Documents\ITMO\Year1\NLP\snatch.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/d%3A/Documents/ITMO/Year1/NLP/snatch.ipynb#ch0000000?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/d%3A/Documents/ITMO/Year1/NLP/snatch.ipynb#ch0000000?line=1'>2</a> import nltk
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/ITMO/Year1/NLP/snatch.ipynb#ch0000000?line=2'>3</a> import trax
#       <a href='vscode-notebook-cell:/d%3A/Documents/ITMO/Year1/NLP/snatch.ipynb#ch0000000?line=3'>4</a> from trax import layers as tl
#       <a href='vscode-notebook-cell:/d%3A/Documents/ITMO/Year1/NLP/snatch.ipynb#ch0000000?line=4'>5</a> from trax.supervised import training
#
# ModuleNotFoundError: No module named 'trax'

# %%
# !pip install trax
# Out:
# Collecting trax
#   Downloading trax-1.4.1-py2.py3-none-any.whl (637 kB)
#      -------------------------------------- 637.9/637.9 KB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\pablo\appdata\local\programs\python\python310\lib\site-packages (from trax) (3.5.1)
# Collecting gin-config
#   Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.3/61.3 KB ? eta 0:00:00
# Collecting jax
#   Downloading jax-0.3.4.tar.gz (924 kB)
#      ------------------------------------- 925.0/925.0 KB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting psutil
#   Downloading psutil-5.9.0-cp310-cp310-win_amd64.whl (245 kB)
#      ------------------------------------- 245.5/245.5 KB 14.7 MB/s eta 0:00:00
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.8.1-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 18.0 MB/s eta 0:00:00
# Collecting gym
#   Downloading gym-0.23.1.tar.gz (626 kB)
#      -------------------------------------- 626.2/626.2 KB 9.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six in c:\users\pablo\appdata\roaming\python\python310\site-packages (from trax) (1.16.0)
# Collecting absl-py
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      -------------------------------------- 126.7/126.7 KB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\pablo\appdata\local\programs\python\python310\lib\site-packages (from trax) (1.8.0)
# Collecting funcsigs
#   Downloading funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Collecting tensorflow-datasets
#   Downloading tensorflow_datasets-4.5.2-py3-none-any.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\pablo\appdata\local\programs\python\python310\lib\site-packages (from trax) (1.22.2)
# Collecting trax
#   Downloading trax-1.4.0-py2.py3-none-any.whl (637 kB)
#      ------------------------------------- 637.8/637.8 KB 13.4 MB/s eta 0:00:00
#   Downloading trax-1.3.9-py2.py3-none-any.whl (629 kB)
#      ------------------------------------- 629.3/629.3 KB 20.0 MB/s eta 0:00:00
# Collecting t5
#   Downloading t5-0.9.3-py3-none-any.whl (153 kB)
#      -------------------------------------- 153.9/153.9 KB 9.6 MB/s eta 0:00:00
# Collecting trax
#   Downloading trax-1.3.8-py2.py3-none-any.whl (617 kB)
#      ------------------------------------- 617.9/617.9 KB 12.9 MB/s eta 0:00:00
#   Downloading trax-1.3.7-py2.py3-none-any.whl (521 kB)
#      ------------------------------------- 521.8/521.8 KB 10.9 MB/s eta 0:00:00
#   Downloading trax-1.3.6-py2.py3-none-any.whl (468 kB)
#      ------------------------------------- 468.3/468.3 KB 14.8 MB/s eta 0:00:00
#   Downloading trax-1.3.5-py2.py3-none-any.whl (416 kB)
#      ------------------------------------- 416.6/416.6 KB 13.1 MB/s eta 0:00:00
#   Downloading trax-1.3.4-py2.py3-none-any.whl (366 kB)
#      ------------------------------------- 366.1/366.1 KB 11.5 MB/s eta 0:00:00
#   Downloading trax-1.3.3-py2.py3-none-any.whl (365 kB)
#      ------------------------------------- 366.0/366.0 KB 11.5 MB/s eta 0:00:00
#   Downloading trax-1.3.2-py2.py3-none-any.whl (365 kB)
#      ------------------------------------- 365.6/365.6 KB 22.2 MB/s eta 0:00:00
#   Downloading trax-1.3.1-py2.py3-none-any.whl (347 kB)
#      ------------------------------------- 347.2/347.2 KB 21.1 MB/s eta 0:00:00
#   Downloading trax-1.3-py2.py3-none-any.whl (346 kB)
#      ------------------------------------- 346.7/346.7 KB 22.4 MB/s eta 0:00:00
#   Downloading trax-1.2.4-py2.py3-none-any.whl (426 kB)
#      ------------------------------------- 426.7/426.7 KB 13.0 MB/s eta 0:00:00
#   Downloading trax-1.2.3-py2.py3-none-any.whl (371 kB)
#      ------------------------------------- 371.6/371.6 KB 11.3 MB/s eta 0:00:00
#   Downloading trax-1.2.2-py2.py3-none-any.whl (311 kB)
#      ------------------------------------- 311.4/311.4 KB 18.8 MB/s eta 0:00:00
#   Downloading trax-1.2.1-py2.py3-none-any.whl (311 kB)
#      ------------------------------------- 311.0/311.0 KB 18.8 MB/s eta 0:00:00
#   Downloading trax-1.2.0-py2.py3-none-any.whl (311 kB)
#      ------------------------------------- 311.0/311.0 KB 20.1 MB/s eta 0:00:00
#   Downloading trax-1.1.4-py2.py3-none-any.whl (309 kB)
#      ------------------------------------- 309.7/309.7 KB 20.0 MB/s eta 0:00:00
#   Downloading trax-1.1.3-py2.py3-none-any.whl (309 kB)
#      -------------------------------------- 309.6/309.6 KB 9.4 MB/s eta 0:00:00
#   Downloading trax-1.1.2-py2.py3-none-any.whl (283 kB)
#      ------------------------------------- 283.8/283.8 KB 18.2 MB/s eta 0:00:00
#   Downloading trax-1.1.1-py2.py3-none-any.whl (270 kB)
#      -------------------------------------- 270.4/270.4 KB 8.4 MB/s eta 0:00:00
#   Downloading trax-1.1.0-py2.py3-none-any.whl (231 kB)
#      ---------------------------------------- 232.0/232.0 KB ? eta 0:00:00
#   Downloading trax-1.0.1-py2.py3-none-any.whl (211 kB)
#      ------------------------------------- 211.7/211.7 KB 12.6 MB/s eta 0:00:00
#   Downloading trax-1.0.0-py2.py3-none-any.whl (207 kB)
#      ------------------------------------- 207.2/207.2 KB 12.3 MB/s eta 0:00:00
#
# The conflict is caused by:
#     trax 1.4.1 depends on jaxlib
#     trax 1.4.0 depends on jaxlib
#     trax 1.3.9 depends on jaxlib
#     trax 1.3.8 depends on jaxlib
#     trax 1.3.7 depends on jaxlib
#     trax 1.3.6 depends on jaxlib
#     trax 1.3.5 depends on jaxlib
#     trax 1.3.4 depends on jaxlib
#     trax 1.3.3 depends on jaxlib
#     trax 1.3.2 depends on jaxlib
#     trax 1.3.1 depends on jaxlib
#     trax 1.3 depends on jaxlib
#     trax 1.2.4 depends on jaxlib
#     trax 1.2.3 depends on jaxlib
#     trax 1.2.2 depends on jaxlib
#     trax 1.2.1 depends on jaxlib
#     trax 1.2.0 depends on jaxlib
#     trax 1.1.4 depends on jaxlib
#     trax 1.1.3 depends on jaxlib
#     trax 1.1.2 depends on jaxlib
#     trax 1.1.1 depends on jaxlib
#     trax 1.1.0 depends on jaxlib
#     trax 1.0.1 depends on jaxlib
#     trax 1.0.0 depends on jaxlib
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
# ERROR: Cannot install trax==1.0.0, trax==1.0.1, trax==1.1.0, trax==1.1.1, trax==1.1.2, trax==1.1.3, trax==1.1.4, trax==1.2.0, trax==1.2.1, trax==1.2.2, trax==1.2.3, trax==1.2.4, trax==1.3, trax==1.3.1, trax==1.3.2, trax==1.3.3, trax==1.3.4, trax==1.3.5, trax==1.3.6, trax==1.3.7, trax==1.3.8, trax==1.3.9, trax==1.4.0 and trax==1.4.1 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
